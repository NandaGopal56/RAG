# %%
import os
from dotenv import load_dotenv
load_dotenv()

print(bool(os.getenv("OPENAI_API_KEY")))
# Out:
# True

# %%
from docx import Document
from langchain_core.documents import Document as LCDocument

def load_docx(path: str):
    doc = Document(path)
    text = "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    return [LCDocument(page_content=text)]

documents = load_docx("Aranya_River_Project.docx")

documents[0].page_content[:500]
# Out:
# 'The Aranya River Project: A Case Study in Infrastructure, Policy, and Human Impact\n\n1. Background and Origin\nThe Aranya River originates in the eastern slopes of the Vindhya mountain range and flows through three Indian states before merging into the Bay of Bengal. For centuries, it supported agriculture, fisheries, and small riverine trade. Seasonal flooding was common but largely predictable, and local communities adapted their farming cycles accordingly.\nIn 2008, recurring droughts in the dow'

# %%
from langchain_text_splitters import TextSplitter

class FixedLineTextSplitter(TextSplitter):
    def __init__(self, lines_per_chunk=5):
        super().__init__()
        self.lines_per_chunk = lines_per_chunk

    def split_text(self, text):
        lines = text.splitlines()
        return [
            "\n".join(lines[i:i + self.lines_per_chunk])
            for i in range(0, len(lines), self.lines_per_chunk)
        ]

splitter = FixedLineTextSplitter(lines_per_chunk=4)
chunks = splitter.split_documents(documents)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i}:")
    print(chunk.page_content)
    print()
# Out:
# Chunk 0:
# The Aranya River Project: A Case Study in Infrastructure, Policy, and Human Impact
#
# 1. Background and Origin
# The Aranya River originates in the eastern slopes of the Vindhya mountain range and flows through three Indian states before merging into the Bay of Bengal. For centuries, it supported agriculture, fisheries, and small riverine trade. Seasonal flooding was common but largely predictable, and local communities adapted their farming cycles accordingly.
#
# Chunk 1:
# In 2008, recurring droughts in the downstream regions triggered renewed interest in large-scale water storage and regulation. The central government commissioned a feasibility study to assess whether a multi-purpose dam could address irrigation shortages, generate hydroelectric power, and control floods.
# The project was officially named the Aranya Integrated River Management Project (AIRMP).
# 2. Initial Feasibility Study (2009–2011)
# The feasibility study was led by HydroSys Consultants, a public-private consortium. Their findings concluded:
#
# Chunk 2:
# - A dam at Kundar Gorge could store up to 4.2 billion cubic meters of water.
# - Approximately 42,000 hectares of land would be submerged.
# - Around 18 villages would require partial or complete relocation.
# - The dam could generate 900 MW of electricity at peak capacity.
#
# Chunk 3:
# The report emphasized that long-term economic benefits outweighed social costs, provided rehabilitation was executed efficiently.
# However, an internal appendix—later leaked—highlighted uncertainties around sediment accumulation and underestimation of displacement numbers.
# 3. Environmental Impact Assessment (EIA)
# An Environmental Impact Assessment was conducted in 2012 by GreenSphere Analytics.
#
# Chunk 4:
# Key findings included:
# - The river supported at least 12 endemic fish species.
# - Seasonal flooding played a critical role in soil nutrient replenishment.
# - The dam would alter groundwater recharge patterns within a 60 km radius.
#
# Chunk 5:
# Despite these findings, the final EIA summary concluded that impacts were manageable with standard mitigation measures.
# 4. Policy Approval and Funding
# In 2013, the project received clearance from the Ministry of Water Resources, Ministry of Power, and concerned state governments.
# Funding structure:
#
# Chunk 6:
# - 55% central government
# - 25% state governments
# - 20% international development bank loan
# 5. Rehabilitation and Resettlement Plan
#
# Chunk 7:
# The Resettlement & Rehabilitation Plan proposed monetary compensation, residential plots, and job preferences.
# Problems included outdated land records, exclusion of tenant farmers, and informal job promises.
# By 2016, less than 40% of affected households had received full compensation.
# 6. Construction Phase (2014–2020)
#
# Chunk 8:
# Construction began in 2014 and faced cost overruns, labor disputes, and a fatal landslide incident in 2017.
# 7. Commissioning and Early Operation
# The dam became operational in 2020. Power generation reached only 62% of projected capacity, and fish populations declined by 35–40% by 2022.
# 8. Socio-Economic Impact
#
# Chunk 9:
# Some displaced families benefited from improved infrastructure, while others lost livelihoods. Around 30% migrated again to urban areas.
# 9. Conflicting Narratives
# Government reports emphasized success, while critics highlighted ecological and social costs.
# 10. Long-Term Review (2023)
#
# Chunk 10:
# An independent review found lower economic returns and underestimated social costs.
# 11. Open Questions
# Sedimentation, ecosystem recovery, and long-term accountability remain unresolved.

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")


vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="./chroma_store"
)

vectorstore.persist()
# Out:
# /var/folders/x2/l10n74v56qz1q_1vk6j6yzr00000gn/T/ipykernel_22529/1540739761.py:13: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %%
query = "What is the Aranya River Project?"

results = vectorstore.similarity_search_with_score(
    query=query,
    k=5
)

for i, (doc, score) in enumerate(results, 1):
    print(f"\n--- Result {i} | Score: {score} ---")
    print(doc.page_content)
# Out:
# --- Result 1 | Score: 0.5425897240638733 ---
# The Aranya River Project: A Case Study in Infrastructure, Policy, and Human Impact
#
# 1. Background and Origin
# The Aranya River originates in the eastern slopes of the Vindhya mountain range and flows through three Indian states before merging into the Bay of Bengal. For centuries, it supported agriculture, fisheries, and small riverine trade. Seasonal flooding was common but largely predictable, and local communities adapted their farming cycles accordingly.
#
# --- Result 2 | Score: 0.7135130763053894 ---
# In 2008, recurring droughts in the downstream regions triggered renewed interest in large-scale water storage and regulation. The central government commissioned a feasibility study to assess whether a multi-purpose dam could address irrigation shortages, generate hydroelectric power, and control floods.
# The project was officially named the Aranya Integrated River Management Project (AIRMP).
# 2. Initial Feasibility Study (2009–2011)
# The feasibility study was led by HydroSys Consultants, a public-private consortium. Their findings concluded:
#
# --- Result 3 | Score: 1.268094539642334 ---
# Key findings included:
# - The river supported at least 12 endemic fish species.
# - Seasonal flooding played a critical role in soil nutrient replenishment.
# - The dam would alter groundwater recharge patterns within a 60 km radius.
#
# --- Result 4 | Score: 1.2830300331115723 ---
# Despite these findings, the final EIA summary concluded that impacts were manageable with standard mitigation measures.
# 4. Policy Approval and Funding
# In 2013, the project received clearance from the Ministry of Water Resources, Ministry of Power, and concerned state governments.
# Funding structure:
#
# --- Result 5 | Score: 1.296705961227417 ---
# - A dam at Kundar Gorge could store up to 4.2 billion cubic meters of water.
# - Approximately 42,000 hectares of land would be submerged.
# - Around 18 villages would require partial or complete relocation.
# - The dam could generate 900 MW of electricity at peak capacity.
